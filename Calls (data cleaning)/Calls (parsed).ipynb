# %% [markdown]
# # To do:
#
#     -> Create dataframe (Done)
#
#     -> Make a class object for transcript data (Done)
#
#     -> Use spAcy or NLTK to parse information (Done)
#
#     -> Construct additional column(s) (Done)
#
#     -> Convert df to csv (Done)

# %%
# Get JSON

import json
with open("calls.json", "r") as f:
    calls = json.load(f)

# %%
# Create Dataframe

import pandas as pd

titles = list(calls[1].keys())

df = pd.DataFrame(columns = titles)

for row_idx in range(len(calls)):
    df.loc[len(df.index)] = calls[row_idx]

df

# %%
# Create Transcripts class

class Transcripts: 
    """
    Transcripts object for more efficient API and scalability.

    Index corresponds to dataframe.
    """
    def __init__(self, transcript: list[dict]):

        self._scripts = []
        for i in transcript:
            temp_dict = {}
            for j in range(len(i)):
                temp_dict[i[j]['user']] = temp_dict.get(i[j]['user'], []) + [(i[j]['text'], j)]
            self._scripts.append(temp_dict)

    def get(self, idx: int, user: None | str = None) -> str:
        """
        If user is not specified will return whole transcript with USER and ASSISTANT labels. Runtime will be O(n + m)

        Otherwise will return the transcript of specified user. Runtime will be O(n) or O(m) respectively.

        """
        
        script = self._scripts[idx]
        res = ''
        
        if not user:
            # Merge two sorted arrays
            arr1 = list(script.get('user', ''))
            arr2 = list(script.get('assistant', ''))
            
            merged = []

            i, j = 0, 0

            while i < len(arr1) and j < len(arr2):
                if arr1[i][1] <= arr2[j][1]:
                    merged.append((arr1[i], 'user'))
                    i += 1
                else:
                    merged.append((arr2[j], 'assistant'))
                    j += 1

            for k in arr1[i:]:
                merged.append((k, 'user'))
            for k in arr2[j:]:
                merged.append((k, 'assistant'))

            for i in merged:
                res += f"{i[1]}: ".upper() + i[0][0] + ' '
        
        else:
            # User is specified
            for i in script.get(user, ''):
                res += i[0] + ' '
        return res

# %%
# Example usage of Transcripts object

transcript = Transcripts(df['transcripts'])

print(transcript.get(2), '\n')
print(transcript.get(2, 'user'), '\n')
print(transcript.get(2, 'assistant'))
# Out:
# USER: Morning. PKF. This is Alicia. ASSISTANT: Yea, are you still located at 1 Bligh Street?
#  USER: No. Sorry. We're at 1 O'Connell Street. ASSISTANT: Great, thanks! [Finish]
#
#
# Morning. PKF. This is Alicia. No. Sorry. We're at 1 O'Connell Street.
#
# Yea, are you still located at 1 Bligh Street?
#  Great, thanks! [Finish]

# %% [markdown]
# # 4 categories:
#
#          -> Yes, No:
#                * The most simple determiner of verification status.
#
#          -> Assistant address:
#                * The address as dictated by the 'assistant'.
#                    $ In other words, the registered address prior to calling.
#
#          -> User address:
#                * The address as dictated by the 'user'.
#                    $ Either a mention or a variation from Assistant address indicates an Address change.
#
#          -> Level:
#
#                * The level (if mentioned) by the 'user.
#                    $ Mentioning the level without uttering a 'no' indicates a likely address confirmation.
#                    $ Verification_status is sparse, meaing that correcting false positives is easier than vice versa.

# %%
"""
    Using en_core_web_sm: the small version of spAcy's english model for time efficiency.
"""

import spacy                            # !pip install spacy
nlp = spacy.load("en_core_web_sm")      # !python -m spacy download en

# %%
user_response = []

for i in range(len(df)):
    doc = nlp(transcript.get(i, 'user'))
    yes_list = [token.text for token in doc if token.lemma_.lower() in ('yes', 'yeah', 'yep')]    
    no_list = [token.text for token in doc if token.lemma_.lower() in ('no', 'nah')]
    if yes_list and not no_list:
        user_response.append('Yes')
    elif no_list and not yes_list:
        user_response.append('No')
    else:
        user_response.append(None)

# %%
import re

"""
    Creating regex pattern to parse address information.
"""

address_endings = ['street', 'avenue', 'road', 'lane', 'drive', 'boulevard',
                    'court', 'place', 'square', 'alley']  

pattern = re.compile(r'\d*\s*([a-zA-Z]+(\s|\'[a-zA-Z]+)*)+\s*(?:' + '|'.join(address_endings) + r's*)', 
                     re.IGNORECASE) # Regex to determine if_address

# %%
assistant_address = []

"""
    Occasionally, python's re.search enters a never-ending loop while parsing certain pieces of text.
    
    A temporary array: temp, is used to reduce the amount of strings passed into re.search.
"""
for i in range(len(df)):
    address = None
    doc = nlp(transcript.get(i, 'assistant'))
    temp = []
    for j in doc.noun_chunks: 
        sentence = str(j)
        for ending in address_endings:
            if ending in sentence.lower():
                temp.append(sentence)
                break
    for s in temp:
        match = pattern.search(s)
        if match:
            address = match.group(0)
            break
    
    assistant_address.append(address)
# Out:
# '25 Martin Place'

# %%
user_address = []

for i in range(len(df)):
    address = None
    doc = nlp(transcript.get(i, 'user'))
    temp = []
    for j in doc.noun_chunks:
        sentence = str(j)
        for ending in address_endings:
            if ending in sentence.lower():
                temp.append(sentence)
                break
    for s in temp:
        match = pattern.search(s)
        if match:
            address = match.group(0)
            break
    
    user_address.append(address)

# %%
level = []

pattern = re.compile(r'\blevel\s+(\d+)\b', re.IGNORECASE)

for i in range(len(df)):
    text = transcript.get(i, 'user')
    match = pattern.search(text)
    res = None
    if match:
        res = match.group(0).capitalize()
    level.append(res)

# %%
df['user_response'] = user_response
df['assistant_address'] = assistant_address
df['user_address'] = user_address
df['level'] = level

# %%
# Verification status

verification_status = ['No Result' for _ in range(len(df))]

df['verification_status'] = verification_status

for i in range(len(df)):
    
    # Check for yes or no
    if df['user_response'][i] == 'Yes':
        df.at[i, 'verification_status'] = 'Address Confirmed'
    elif df['user_response'][i] == 'No':
        df.at[i, 'verification_status'] = 'Address Changed'
    
    # Check if user address is different from assistant address
    if df['assistant_address'][i] and df['user_address'][i]:
        if df['assistant_address'][i] != df['user_address'][i]:
            df.at[i, 'verification_status'] = 'Address Changed' # Don't have to check vice versa
    
    # Check if level was mentioned
    if not df['verification_status'][i] == 'Address Changed' and df['level'][i]:
        df.at[i, 'verification_status'] = 'Address Confirmed'
                   
df
# Out:
#        status corrected_duration                    end_at  \
# 0   completed                  7  2023-12-07T22:03:14.000Z
# 1   completed                 28  2023-12-07T22:02:58.000Z
# 2   completed                 78  2023-12-07T22:04:14.000Z
# 3   completed                 10  2023-12-07T22:02:42.000Z
# 4   completed                 35  2023-12-07T22:03:06.000Z
# 5   completed                 18  2023-12-07T22:02:51.000Z
# 6   completed                 80  2023-12-07T22:03:45.000Z
# 7   completed                 85  2023-12-07T22:03:54.000Z
# 8   completed                 13  2023-12-07T22:02:48.000Z
# 9   completed                  3  2023-12-07T22:02:45.000Z
# 15             5          None
# 16             5          None
# 17             5          None
# 18             5          None
# 19             5          None
# 20             5          None
# 21             5          None
# 22             5          None
# 23             5          None
# 24             5          None
# 25             5          None
# 26             5          None
# 27             5          None
# 28             5          None
# 29             5          None
# 30             5          None
# 31             5          None
# 32             5          None
# 33             5          None
# 34             5          None
# 35             5          None
# 36             5          None
# 37             5          None
# 38             5          None
# 39             5          None
# 40             5          None
# 41             5          None
# 42             5          None
# 43             5          None
# 44             5          None
# 45             5          None
# 46             5          None
#
#                                          request_data  \
# 0   {'phone_number': '+61285027935', 'reduce_laten...
# 1   {'phone_number': '+61283791854', 'reduce_laten...
# 2   {'phone_number': '+61283466000', 'reduce_laten...
# 3   {'phone_number': '+61283073595', 'reduce_laten...
# 4   {'phone_number': '+61282599999', 'reduce_laten...
# 5   {'phone_number': '+61282415600', 'reduce_laten...
# 6   {'phone_number': '+61282393555', 'reduce_laten...
# 7   {'phone_number': '+61282393555', 'reduce_laten...
# 8   {'phone_number': '+61282366000', 'reduce_laten...
# 9   {'phone_number': '+61282279600', 'reduce_laten...
# 10  {'phone_number': '+61282277400', 'reduce_laten...
# 11  {'phone_number': '+61282275500', 'reduce_laten...
# 12  {'phone_number': '+61282269600', 'reduce_laten...
# 13  {'phone_number': '+61282269000', 'reduce_laten...
# 14  {'phone_number': '+61282268785', 'reduce_laten...
# 15  {'phone_number': '+61282268626', 'reduce_laten...
# 16  {'phone_number': '+61282268616', 'reduce_laten...
# 17  {'phone_number': '+61282268526', 'reduce_laten...
# 18  {'phone_number': '+61282268501', 'reduce_laten...
# 19  {'phone_number': '+61282173888', 'reduce_laten...
# 20  {'phone_number': '+61282173804', 'reduce_laten...
# 21  {'phone_number': '+61282157900', 'reduce_laten...
# 22  {'phone_number': '+61282112701', 'reduce_laten...
# 23  {'phone_number': '+61281887590', 'reduce_laten...
# 24  {'phone_number': '+61281881151', 'reduce_laten...
# 25  {'phone_number': '+61280981504', 'reduce_laten...
# 26  {'phone_number': '+61280902386', 'reduce_laten...
# 27  {'phone_number': '+61280881800', 'reduce_laten...
# 28  {'phone_number': '+61280808074', 'reduce_laten...
# 29  {'phone_number': '+61280766627', 'reduce_laten...
# 30  {'phone_number': '+61280766600', 'reduce_laten...
# 31  {'phone_number': '+61280762210', 'reduce_laten...
# 32  {'phone_number': '+61280754500', 'reduce_laten...
# 33  {'phone_number': '+61280678740', 'reduce_laten...
# 34  {'phone_number': '+61280669099', 'reduce_laten...
# 35  {'phone_number': '+61280408993', 'reduce_laten...
# 36  {'phone_number': '+61280392222', 'reduce_laten...
# 37  {'phone_number': '+61280383300', 'reduce_laten...
# 38  {'phone_number': '+61280169394', 'reduce_laten...
# 39  {'phone_number': '+61280169375', 'reduce_laten...
# 40  {'phone_number': '+61280169212', 'reduce_laten...
# 41  {'phone_number': '+61280114580', 'reduce_laten...
# 42  {'phone_number': '+61280074944', 'reduce_laten...
# 43  {'phone_number': '+61280034445', 'reduce_laten...
# 44  {'phone_number': '+61272277336', 'reduce_laten...
# 45  {'phone_number': '+61249247200', 'reduce_laten...
# 46  {'phone_number': '+61242017031', 'reduce_laten...
#
#                                           transcripts  call_length  \
# 0   [{'id': 1109683, 'created_at': '2023-12-07T22:...        4.903
# 1   [{'id': 1109572, 'created_at': '2023-12-07T22:...       17.699
# 2   [{'id': 1109728, 'created_at': '2023-12-07T22:...       10.053
# 3   [{'id': 1109580, 'created_at': '2023-12-07T22:...        0.590
# 4   [{'id': 1109555, 'created_at': '2023-12-07T22:...       30.963
# 5   [{'id': 1109567, 'created_at': '2023-12-07T22:...       12.882
# 6   [{'id': 1109658, 'created_at': '2023-12-07T22:...       41.438
# 7   [{'id': 1109689, 'created_at': '2023-12-07T22:...        0.599
# 8   [{'id': 1109566, 'created_at': '2023-12-07T22:...        7.860
# 9   [{'id': 1109591, 'created_at': '2023-12-07T22:...        1.975
# 10  [{'id': 1109525, 'created_at': '2023-12-07T22:...       45.258
# 11  [{'id': 1109645, 'created_at': '2023-12-07T22:...        8.353
# 12  [{'id': 1109713, 'created_at': '2023-12-07T22:...       12.593
# 13  [{'id': 1109538, 'created_at': '2023-12-07T22:...       47.357
# 14  [{'id': 1109680, 'created_at': '2023-12-07T22:...        6.595
# 15  [{'id': 1109560, 'created_at': '2023-12-07T22:...       31.038
# 16  [{'id': 1109637, 'created_at': '2023-12-07T22:...       12.644
# 17  [{'id': 1109627, 'created_at': '2023-12-07T22:...       12.669
# 18  [{'id': 1109499, 'created_at': '2023-12-07T22:...        4.366
# 19  [{'id': 1109468, 'created_at': '2023-12-07T22:...       10.741
# 20  [{'id': 1109532, 'created_at': '2023-12-07T22:...        0.000
# 21  [{'id': 1109507, 'created_at': '2023-12-07T22:...       41.309
# 22  [{'id': 1109625, 'created_at': '2023-12-07T22:...        0.761
# 23  [{'id': 1109574, 'created_at': '2023-12-07T22:...        0.627
# 24  [{'id': 1109533, 'created_at': '2023-12-07T22:...        0.480
# 25  [{'id': 1109489, 'created_at': '2023-12-07T22:...       18.932
# 26  [{'id': 1109491, 'created_at': '2023-12-07T22:...        9.256
# 27  [{'id': 1109460, 'created_at': '2023-12-07T22:...        4.850
# 28  [{'id': 1109602, 'created_at': '2023-12-07T22:...        0.843
# 29  [{'id': 1109454, 'created_at': '2023-12-07T22:...        7.220
# 30  [{'id': 1109503, 'created_at': '2023-12-07T22:...        2.379
# 31  [{'id': 1109476, 'created_at': '2023-12-07T22:...       10.700
# 32  [{'id': 1109488, 'created_at': '2023-12-07T22:...       10.699
# 33  [{'id': 1109606, 'created_at': '2023-12-07T22:...       34.331
# 34  [{'id': 1109616, 'created_at': '2023-12-07T22:...        0.428
# 35  [{'id': 1109462, 'created_at': '2023-12-07T22:...       34.066
# 36  [{'id': 1109470, 'created_at': '2023-12-07T22:...       15.675
# 37  [{'id': 1109441, 'created_at': '2023-12-07T22:...        6.818
# 38  [{'id': 1109463, 'created_at': '2023-12-07T22:...       27.190
# 39  [{'id': 1109458, 'created_at': '2023-12-07T22:...       10.069
# 40  [{'id': 1109440, 'created_at': '2023-12-07T22:...       24.150
# 41  [{'id': 1109477, 'created_at': '2023-12-07T22:...       69.071
# 42  [{'id': 1109539, 'created_at': '2023-12-07T22:...        0.988
# 43  [{'id': 1109471, 'created_at': '2023-12-07T22:...        0.804
# 44  [{'id': 1109465, 'created_at': '2023-12-07T22:...       27.641
# 45  [{'id': 1109435, 'created_at': '2023-12-07T22:...       17.415
# 46  [{'id': 1109434, 'created_at': '2023-12-07T22:...       12.136
#
#    user_response assistant_address         user_address     level  \
# 0           None    1 Bligh Street                 None      None
# 1             No   25 Martin Place                 None      None
# 2             No    1 Bligh Street   1 O'Connell Street      None
# 3           None              None                 None      None
# 4           None  2 Chifley Square                 None      None
# 5           None   25 Martin Place                 None  Level 32
# 6            Yes   25 Martin Place                 None  Level 51
# 7           None              None                 None      None
# 8           None  2 Chifley Square                 None      None
# 9           None   52 Martin Place                 None      None
# 10           Yes  2 Chifley Square                 None      None
# 11           Yes  2 Chifley Square                 None      None
# 12          None  2 Chifley Square                 None      None
# 13          None  2 Chifley Square                 None      None
# 14          None    1 Bligh Street                 None      None
# 15          None    1 Bligh Street                 None      None
# 16          None    1 Bligh Street                 None      None
# 17          None    1 Bligh Street                 None      None
# 18          None              None                 None      None
# 19          None  2 Chifley Square                 None      None
# 20          None              None                 None      None
# 21          None   25 Martin Place                 None      None
# 22          None              None                 None      None
# 23          None              None                 None      None
# 24          None              None                 None      None
# 25           Yes   25 Martin Place                 None      None
# 26          None    1 Bligh Street                 None      None
# 27          None    1 Bligh Street                 None      None
# 28          None              None                 None      None
# 29           Yes   25 Martin Place                 None  Level 64
# 30          None              None                 None      None
# 31          None   25 Martin Place                 None      None
# 32          None   25 Martin Place                 None      None
# 33          None   25 Martin Place                 None      None
# 34          None              None                 None      None
# 35            No              None                 None      None
# 36           Yes  2 Chifley Square                 None      None
# 37          None              None                 None      None
# 38          None    1 Bligh Street                 None      None
# 39           Yes    1 Bligh Street                 None      None
# 40          None  2 Chifley Square                 None      None
# 41          None   25 Martin Place                 None      None
# 42          None              None                 None      None
# 43          None              None                 None      None
# 44          None   25 Martin Place  3 Hillsborough Road      None
# 45          None   25 Martin Place                 None      None
# 46          None    1 Bligh Street                 None      None
#
#    verification_status
# 0            No Result
# 1      Address Changed
# 2      Address Changed
# 3            No Result
# 4            No Result
# 5    Address Confirmed
# 6    Address Confirmed
# 7            No Result
# 8            No Result
# 9            No Result
# 10   Address Confirmed
# 11   Address Confirmed
# 12           No Result
# 13           No Result
# 14           No Result
# 15           No Result
# 16           No Result
# 17           No Result
# 18           No Result
# 19           No Result
# 20           No Result
# 21           No Result
# 22           No Result
# 23           No Result
# 24           No Result
# 25   Address Confirmed
# 26           No Result
# 27           No Result
# 28           No Result
# 29   Address Confirmed
# 30           No Result
# 31           No Result
# 32           No Result
# 33           No Result
# 34           No Result
# 35     Address Changed
# 36   Address Confirmed
# 37           No Result
# 38           No Result
# 39   Address Confirmed
# 40           No Result
# 41           No Result
# 42           No Result
# 43           No Result
# 44     Address Changed
# 45           No Result
# 46           No Result

# %%
# Convert to CSV

df.to_csv(r'.\output.csv', index=False)
